# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    "Age": [22, 25, 47, 52, 23, 40, 60, 35, 45, 38],
    "Income": [25000, 45000, 100000, 80000, 35000, 60000, 120000, 55000, 75000, 68000],
    "Gender": [
        "Male",
        "Female",
        "Female",
        "Male",
        "Female",
        "Male",
        "Male",
        "Female",
        "Male",
        "Female",
    ],
    "Purchase": [0, 1, 1, 0, 1, 1, 0, 1, 0, 1],
}

df = pd.DataFrame(data)
print(df)
print("First 5 rows:\n", df.head())
print("\nSummary statistics:\n", df.describe())
print("\nMissing values:\n", df.isnull().sum())
# Out:
#    Age  Income  Gender  Purchase
# 0   22   25000    Male         0
# 1   25   45000  Female         1
# 2   47  100000  Female         1
# 3   52   80000    Male         0
# 4   23   35000  Female         1
# 5   40   60000    Male         1
# 6   60  120000    Male         0
# 7   35   55000  Female         1
# 8   45   75000    Male         0
# 9   38   68000  Female         1
# First 5 rows:
#     Age  Income  Gender  Purchase
# 0   22   25000    Male         0
# 1   25   45000  Female         1
# 2   47  100000  Female         1
# 3   52   80000    Male         0
# 4   23   35000  Female         1
#
# Summary statistics:
#               Age         Income   Purchase
# count  10.000000      10.000000  10.000000
# mean   38.700000   66300.000000   0.600000
# std    12.771931   29044.219161   0.516398
# min    22.000000   25000.000000   0.000000
# 25%    27.500000   47500.000000   0.000000
# 50%    39.000000   64000.000000   1.000000
# 75%    46.500000   78750.000000   1.000000
# max    60.000000  120000.000000   1.000000
#
# Missing values:
#  Age         0
# Income      0
# Gender      0
# Purchase    0
# dtype: int64

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 6))
sns.histplot(df["Age"], kde=True, color="blue", bins=10, ax=ax[0])
ax[0].set_title("Age Distribution")
sns.histplot(df["Income"], kde=True, color="green", bins=10, ax=ax[1])
ax[1].set_title("Income Distribution")
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 6))
sns.boxplot(y=df["Age"], color="blue", ax=ax[0])
ax[0].set_title("Boxplot of Age")
sns.boxplot(x=df["Income"], color="green", ax=ax[1])
ax[1].set_title("Boxplot of Income")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x="Gender", data=df, palette="Set2")
plt.title("Gender Distribution")
plt.show()
# Out:
# /tmp/ipykernel_8281/4015456743.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Gender", data=df, palette="Set2")

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x="Purchase", data=df, palette="Set1")
plt.title("Purchase Class Distribution")
plt.show()
# Out:
# /tmp/ipykernel_8281/3892359114.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Purchase", data=df, palette="Set1")

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(df[["Age", "Income"]].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.pairplot(df, hue="Purchase", palette="Set1", vars=["Age", "Income"])
plt.suptitle("Pairplot for Features vs Purchase", y=1.02)
plt.show()

# %%
df = pd.DataFrame(data)
print(df)
print("First 5 rows:\n", df.head())
print("\nSummary statistics:\n", df.describe())
print("\nMissing values:\n", df.isnull().sum())
# Out:
#    Age  Income  Gender  Purchase
# 0   22   25000    Male         0
# 1   25   45000  Female         1
# 2   47  100000  Female         1
# 3   52   80000    Male         0
# 4   23   35000  Female         1
# 5   40   60000    Male         1
# 6   60  120000    Male         0
# 7   35   55000  Female         1
# 8   45   75000    Male         0
# 9   38   68000  Female         1
# First 5 rows:
#     Age  Income  Gender  Purchase
# 0   22   25000    Male         0
# 1   25   45000  Female         1
# 2   47  100000  Female         1
# 3   52   80000    Male         0
# 4   23   35000  Female         1
#
# Summary statistics:
#               Age         Income   Purchase
# count  10.000000      10.000000  10.000000
# mean   38.700000   66300.000000   0.600000
# std    12.771931   29044.219161   0.516398
# min    22.000000   25000.000000   0.000000
# 25%    27.500000   47500.000000   0.000000
# 50%    39.000000   64000.000000   1.000000
# 75%    46.500000   78750.000000   1.000000
# max    60.000000  120000.000000   1.000000
#
# Missing values:
#  Age         0
# Income      0
# Gender      0
# Purchase    0
# dtype: int64

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 6))
sns.histplot(df["Age"], kde=True, color="blue", bins=10, ax=ax[0])
ax[0].set_title("Age Distribution")
sns.histplot(df["Income"], kde=True, color="green", bins=10, ax=ax[1])
ax[1].set_title("Income Distribution")
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 6))
sns.boxplot(y=df["Age"], color="blue", ax=ax[0])
ax[0].set_title("Boxplot of Age")
sns.boxplot(x=df["Income"], color="green", ax=ax[1])
ax[1].set_title("Boxplot of Income")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x="Gender", data=df, palette="Set2")
plt.title("Gender Distribution")
plt.show()
# Out:
# /tmp/ipykernel_8281/4015456743.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Gender", data=df, palette="Set2")

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x="Purchase", data=df, palette="Set1")
plt.title("Purchase Class Distribution")
plt.show()
# Out:
# /tmp/ipykernel_8281/3892359114.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Purchase", data=df, palette="Set1")

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(df[["Age", "Income"]].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.pairplot(df, hue="Purchase", palette="Set1", vars=["Age", "Income"])
plt.suptitle("Pairplot for Features vs Purchase", y=1.02)
plt.show()
