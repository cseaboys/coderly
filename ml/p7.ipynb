# %%
#pip( and winget) install graphviz
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler

iris = load_iris()
X = iris.data 
y = iris.target.reshape(-1, 1)  

encoder = OneHotEncoder(sparse_output=False)
y_encoded = encoder.fit_transform(y)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.2, random_state=42)

model = Sequential()

model.add(Dense(8, input_dim=4, activation='relu'))

model.add(Dense(3, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=50, batch_size=5, verbose=1)

loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# Epoch 1/50
# 24/24 [==============================] - 0s 2ms/step - loss: 1.3657 - accuracy: 0.2500
# Epoch 2/50
# 24/24 [==============================] - 0s 2ms/step - loss: 1.2571 - accuracy: 0.2667
# Epoch 3/50
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1598 - accuracy: 0.2917
# Epoch 4/50
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0735 - accuracy: 0.3500
# Epoch 5/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9981 - accuracy: 0.4167
# Epoch 6/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9267 - accuracy: 0.4833
# Epoch 7/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8650 - accuracy: 0.5833
# Epoch 8/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8100 - accuracy: 0.6250
# Epoch 9/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7624 - accuracy: 0.6500
# Epoch 10/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7191 - accuracy: 0.6500
# Epoch 11/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6817 - accuracy: 0.6667
# Epoch 12/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6481 - accuracy: 0.6750
# Epoch 13/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6200 - accuracy: 0.6833
# Epoch 14/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5940 - accuracy: 0.7000
# Epoch 15/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5706 - accuracy: 0.7250
# Epoch 16/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5507 - accuracy: 0.7333
# Epoch 17/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5320 - accuracy: 0.7417
# Epoch 18/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5142 - accuracy: 0.7750
# Epoch 19/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4984 - accuracy: 0.7833
# Epoch 20/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4830 - accuracy: 0.7917
# Epoch 21/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4687 - accuracy: 0.8083
# Epoch 22/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4557 - accuracy: 0.8250
# Epoch 23/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4430 - accuracy: 0.8250
# Epoch 24/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4314 - accuracy: 0.8250
# Epoch 25/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4206 - accuracy: 0.8333
# Epoch 26/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4098 - accuracy: 0.8417
# Epoch 27/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3995 - accuracy: 0.8500
# Epoch 28/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3899 - accuracy: 0.8583
# Epoch 29/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3811 - accuracy: 0.8583
# Epoch 30/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3712 - accuracy: 0.8750
# Epoch 31/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3628 - accuracy: 0.8750
# Epoch 32/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3541 - accuracy: 0.8833
# Epoch 33/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3464 - accuracy: 0.8833
# Epoch 34/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3378 - accuracy: 0.8917
# Epoch 35/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3302 - accuracy: 0.8917
# Epoch 36/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3222 - accuracy: 0.9167
# Epoch 37/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3137 - accuracy: 0.9250
# Epoch 38/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3063 - accuracy: 0.9250
# Epoch 39/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2987 - accuracy: 0.9333
# Epoch 40/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2917 - accuracy: 0.9417
# Epoch 41/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2843 - accuracy: 0.9417
# Epoch 42/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2762 - accuracy: 0.9417
# Epoch 43/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2697 - accuracy: 0.9500
# Epoch 44/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2625 - accuracy: 0.9500
# Epoch 45/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2559 - accuracy: 0.9500
# Epoch 46/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2497 - accuracy: 0.9500
# Epoch 47/50
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2436 - accuracy: 0.9500
# Epoch 48/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2370 - accuracy: 0.9500
# Epoch 49/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2313 - accuracy: 0.9500
# Epoch 50/50
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2263 - accuracy: 0.9500
# 1/1 [==============================] - 0s 104ms/step - loss: 0.1951 - accuracy: 0.9667
# Test Accuracy: 96.67%

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, show_shapes=True, show_layer_names=True)
